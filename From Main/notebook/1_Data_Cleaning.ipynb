# %%
import pandas as pd  # For data manipulation and analysis
import numpy as np   # For numerical operations

# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For handling missing values
from sklearn.impute import SimpleImputer  # If using scikit-learn for imputation

# %%
df = pd.read_csv('/Users/eawe.fellow/Desktop/NYC Energy Consumption Data Sci Caostone/Data 2/raw/Electric_Consumption_And_Cost__2010_-_Feb_2023__20240417.csv')
# Out:
# /var/folders/yz/n572n2w51t30htrrgdgw384m0000gq/T/ipykernel_49056/151010280.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/eawe.fellow/Desktop/NYC Energy Consumption Data Sci Caostone/Data 2/raw/Electric_Consumption_And_Cost__2010_-_Feb_2023__20240417.csv')

# %%
df.isnull()
# Out:
#         Development Name  Borough  Account Name  Location  Meter AMR  \
# 0                  False    False         False     False      False
# 1                  False    False         False     False      False
# 2                  False    False         False     False      False
# 3                  False    False         False     False      False
# 4                  False    False         False     False      False
# ...                  ...      ...           ...       ...        ...
# 447844             False    False         False     False      False
# 447845             False    False         False     False      False
# 447846             False    False         False     False      False
# 447847             False    False         False     False      False
# 447848             False    False         False     False      False
#
#         Meter Scope  TDS #    EDP  RC Code  Funding Source  ...  Meter Number  \
# ...

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of        Development Name   Borough     Account Name Location Meter AMR  \
# 0                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 1                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 2                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 3                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 4                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# ...                 ...       ...              ...      ...       ...
# 447844  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03  INTERVAL
# 447845  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03  INTERVAL
# 447846  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 02       AMR
# 447847  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03       AMR
# 447848  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03       AMR
#
#          Meter Scope  TDS #  EDP  RC Code Funding Source  ... Meter Number  \
# ...

# %%
df.head(5)
# Out:
#   Development Name Borough Account Name Location Meter AMR   Meter Scope  \
# 0            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 1            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 2            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 3            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 4            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
#
#    TDS #  EDP  RC Code Funding Source  ... Meter Number Estimated  \
# 0  118.0  248  B011800        FEDERAL  ...      7223256         N
# 1  118.0  248  B011800        FEDERAL  ...      7223256         N
# 2  118.0  248  B011800        FEDERAL  ...      7223256         N
# 3  118.0  248  B011800        FEDERAL  ...      7223256         N
# 4  118.0  248  B011800        FEDERAL  ...      7223256         N
#
#    Current Charges   Rate Class Bill Analyzed Consumption (KWH)  KWH Charges  \
# ...

# %%
df.columns
# Out:
# Index(['Development Name', 'Borough', 'Account Name', 'Location', 'Meter AMR',
#        'Meter Scope', 'TDS #', 'EDP', 'RC Code', 'Funding Source', 'AMP #',
#        'Vendor Name', 'UMIS BILL ID', 'Revenue Month', 'Service Start Date',
#        'Service End Date', '# days', 'Meter Number', 'Estimated',
#        'Current Charges', 'Rate Class', 'Bill Analyzed', 'Consumption (KWH)',
#        'KWH Charges', 'Consumption (KW)', 'KW Charges', 'Other charges'],
#       dtype='object')

# %%
new_df = df.drop(columns=['EDP', 'AMP #', 'RC Code', 'UMIS BILL ID'])
new_df
# Out:
#        Development Name   Borough     Account Name Location Meter AMR  \
# 0                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 1                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 2                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 3                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# 4                 ADAMS     BRONX            ADAMS   BLD 05      NONE
# ...                 ...       ...              ...      ...       ...
# 447844  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03  INTERVAL
# 447845  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03  INTERVAL
# 447846  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 02       AMR
# 447847  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03       AMR
# 447848  WYCKOFF GARDENS  BROOKLYN  WYCKOFF GARDENS   BLD 03       AMR
#
#          Meter Scope  TDS # Funding Source               Vendor Name  \
# ...

# %%
new_df.describe()
# Out:
#                TDS #         # days  Current Charges  Consumption (KWH)  \
# count  445111.000000  447841.000000     4.478490e+05       4.478490e+05
# mean      117.512099      30.447960     4.277735e+03       3.115645e+04
# std       128.881800       1.898483     8.071365e+03       4.896050e+04
# min         1.000000       1.000000    -1.068744e+04       0.000000e+00
# 25%        33.000000      29.000000     6.275200e+02       0.000000e+00
# 50%        64.000000      30.000000     2.313950e+03       1.340000e+04
# 75%       150.000000      32.000000     5.606110e+03       4.608000e+04
# max       582.000000     396.000000     3.551569e+06       1.779600e+06
#
#         KWH Charges  Consumption (KW)     KW Charges  Other charges
# count  4.478490e+05     447849.000000  447849.000000   4.478490e+05
# mean   1.431691e+03         63.944056     903.329622   1.942714e+03
# std    3.468343e+03        627.156668    1567.021090   4.679456e+03
# ...
